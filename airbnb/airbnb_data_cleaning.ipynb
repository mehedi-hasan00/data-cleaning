# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../airbnb/Airbnb_Open_Data.csv')
# Out:
# /var/folders/cz/bmrbdd0d2kq08ttprs_7dftr0000gn/T/ipykernel_75336/2937942561.py:1: DtypeWarning: Columns (0: license) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../airbnb/Airbnb_Open_Data.csv')

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  str
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  str
#  4   host name                       102193 non-null  str
#  5   neighbourhood group             102570 non-null  str
#  6   neighbourhood                   102583 non-null  str
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  str
#  10  country code                    102468 non-null  str
#  11  instant_bookable                102494 non-null  object
# ...

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']
columns_to_drop = ['reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license','id']

# %%
df = df[columns_to_keep]

# %% [markdown]
# - Renaming the columns
# - Droping duplicates
# - Cleaning individual columns
# - Remove the null values from the dataset
# - Check for some more Transformation

# %%
df.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='str')

# %%
df.rename(columns={'NAME':'name'})
# Out:
#                                                     name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ','_')

# %%
df
# Out:
#                                                     name      host_id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host_name neighbourhood_group  \
# ...

# %%
#remove duplicates values

# %%
df.duplicated().value_counts()
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(541)

# %%
df[df.duplicated()]
# Out:
#                                                     name      host_id  \
# 102058    Master Bedroom with private Bathroom & Balcony  55110690425
# 102059                Cozy 2 br in sunny Fort Greene apt  80193772189
# 102060               Duplex w/ Terrace @ Box House Hotel  72991962259
# 102061      Cozy, clean Greenpoint room with yard access  74975156081
# 102062  2BR XL Loft: Cleaning CDC guidelines implemented  85844415221
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified            host_name neighbourhood_group  \
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#remove the nan value from the dataset

# %%
df.isnull().sum()
# Out:
# name                        250
# host_id                       0
# host_identity_verified      289
# host_name                   404
# neighbourhood_group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country_code                131
# instant_bookable            105
# cancellation_policy          76
# room_type                     0
# construction_year           214
# price                       247
# service_fee                 273
# minimum_nights              400
# number_of_reviews           183
# last_review               15832
# dtype: int64

# %%
df[df.last_review.isnull()]
# Out:
#                                                      name      host_id  \
# 2                     THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 20                      Huge 2 BR Upper East  Cental Park  79805143117
# 27      Magnifique Suite au N de Manhattan - vue Cloitres  38811420224
# 37                            Clean and Quiet in Brooklyn  26207748876
# 39                              Country space in the city  49725315867
# ...                                                   ...          ...
# 102035   rooms in sunny Loft right off the Bedford L stop   6043744134
# 102037                                       Bx Apartment  11038605149
# 102045        Private Bedroom in Rego Park / Forest Hills  15978912806
# 102051                A cozy getaway, home away from home  55697801194
# 102056         Room & private bathroom in historic Harlem  15593031571
#
#        host_identity_verified host_name neighbourhood_group  \
# ...

# %%
df[df['number_of_reviews'] == 0]['last_review'].isnull().sum()
# Out:
# np.int64(15673)

# %% [markdown]
# ### near 99% was null when number of review was 0. No reviews were done. data did not loss of data

# %%
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df['last_review'].dtype
# Out:
# dtype('<M8[us]')

# %%
df.loc[df['number_of_reviews'] == 0,'last_review'] = pd.NaT

# %%
df.sample(7)
# Out:
#                                                      name      host_id  \
# 1028                    Gorgeous ! Best Location in NYC !  21668537709
# 101534  Fully furnished room on 110th St Broadway for ...  68946396234
# 86990     Private bedroom in 2 bedroom, 2 bath- apartment  96729248606
# 76373     Beautiful Private Room near Columbia University  41687056715
# 67090   Plaza Room for Rent Private Entrance Outdoor S...  69653023037
# 25618     Prime Midtown Location - Near Tourist Locations  44279755189
# 61915   Monthly stays @ Murray Hill /2 bedrooms 1 bath...  15305325079
#
#        host_identity_verified host_name neighbourhood_group  \
# 1028                 verified     Lynda           Manhattan
# 101534            unconfirmed     Ankit           Manhattan
# 86990             unconfirmed    Joshua            Brooklyn
# 76373                verified   Gabriel           Manhattan
# 67090                verified     Renee           Manhattan
# ...

# %%
df['last_review'].isnull().sum()
# Out:
# np.int64(15832)

# %%
df.isnull().sum()
# Out:
# name                        250
# host_id                       0
# host_identity_verified      289
# host_name                   404
# neighbourhood_group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country_code                131
# instant_bookable            105
# cancellation_policy          76
# room_type                     0
# construction_year           214
# price                       247
# service_fee                 273
# minimum_nights              400
# number_of_reviews           183
# last_review               15832
# dtype: int64

# %%
df.dropna(subset = ['name'], inplace = True)

# %%
df.isnull().sum()
# Out:
# name                          0
# host_id                       0
# host_identity_verified      277
# host_name                   398
# neighbourhood_group          27
# neighbourhood                16
# lat                           8
# long                          8
# country                     527
# country_code                123
# instant_bookable             97
# cancellation_policy          71
# room_type                     0
# construction_year           205
# price                       244
# service_fee                 273
# minimum_nights              394
# number_of_reviews           182
# last_review               15796
# dtype: int64

# %%
df[df['host_identity_verified'].isnull()]
# Out:
#                                                   name      host_id  \
# 2                  THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 6                                      BlissArtsSpace!  61300605564
# 19     Hip Historic Brownstone Apartment with Backyard  72145018858
# 23                            CBG Helps Haiti Room#2.5  87668933180
# 25              MAISON DES SIRENES1,bohemian apartment  48387947293
# ...                                                ...          ...
# 96336                                  Ma-Don Hideaway  73975905498
# 96337            Gorgeous room in luxury apartment (2)  50042663518
# 96338                                The Yorkville Gem  16811944489
# 96339                1940's Historic Brooklyn Townhome  73143337197
# 96340    Sunny, CENTRAL Williamsburg Room with Rooftop   6659859418
#
#       host_identity_verified        host_name neighbourhood_group  \
# 2                        NaN            Elise           Manhattan
# ...

# %%
df.sample(10)
# Out:
#                                                     name      host_id  \
# 80238                              PEACE AND TRANQUILITY  94270231525
# 71947                 Spacious Chelsea Penthouse w/roof!  52999473471
# 4189                  Cozy & modern 1 br apt in Brooklyn  83515409751
# 7365                 CHARMING NYC Studio Loft NEAR SOHO!  52325967620
# 8096                                         Orange Room   3117838491
# 17498                             Cosy flat West Village  31957905284
# 15662                             Quiet room in Bed-Stuy  60659545477
# 64016  Exclusive Standard Accommodation at Times SQ H...  69957923637
# 79964   Private Room in Homey Roosevelt Island Apartment  53773634141
# 94966          Lovely room with private terrace, ensuite  67932103374
#
#       host_identity_verified   host_name neighbourhood_group  \
# 80238               verified     Pauline               Bronx
# 71947            unconfirmed       Kevin           Manhattan
# ...

# %% [markdown]
# ### nothing find to recover the null value of `host_identity_verified` so i've to drop the null value

# %%
df.dropna(subset=['host_identity_verified'], inplace = True)

# %%
df.isnull().sum()
# Out:
# name                          0
# host_id                       0
# host_identity_verified        0
# host_name                   397
# neighbourhood_group          20
# neighbourhood                16
# lat                           8
# long                          8
# country                     527
# country_code                119
# instant_bookable             93
# cancellation_policy          71
# room_type                     0
# construction_year           193
# price                       240
# service_fee                 272
# minimum_nights              385
# number_of_reviews           182
# last_review               15756
# dtype: int64

# %% [markdown]
# #### host name is not replaceable by any data so i've to drop nan value of this column

# %%
df.dropna(subset=['host_name'], inplace = True)

# %%
df.isnull().sum()
# Out:
# name                          0
# host_id                       0
# host_identity_verified        0
# host_name                     0
# neighbourhood_group          19
# neighbourhood                16
# lat                           8
# long                          8
# country                     526
# country_code                118
# instant_bookable             92
# cancellation_policy          70
# room_type                     0
# construction_year           188
# price                       235
# service_fee                 267
# minimum_nights              385
# number_of_reviews           182
# last_review               15677
# dtype: int64

# %%
df.dropna(subset=['neighbourhood_group','neighbourhood','lat','long'], inplace = True)

# %%
df.isnull().sum()
# Out:
# name                          0
# host_id                       0
# host_identity_verified        0
# host_name                     0
# neighbourhood_group           0
# neighbourhood                 0
# lat                           0
# long                          0
# country                     523
# country_code                115
# instant_bookable             89
# cancellation_policy          67
# room_type                     0
# construction_year           186
# price                       233
# service_fee                 267
# minimum_nights              384
# number_of_reviews           182
# last_review               15674
# dtype: int64

# %%
df[df['country'].isnull()]
# Out:
#                                                   name      host_id  \
# 156                  Sunny, clean 1 bdrm in W. Village  75987317883
# 157                     Great location in Williamsburg  51756716507
# 158     Light and Airy Upper East Side 1 BDR apartment  30351473270
# 159                   Luxury Brownstone in Boerum Hill  22525653405
# 160                      CENTRAL PARK LOFT all for YOU  82585795978
# ...                                                ...          ...
# 101368     Charming Park Slope Apt (fits up to 6 ppl)!   2778317625
# 101369                        Studio with amazing view  25057683830
# 101370     Private apartment in new Brooklyn building!  35509233859
# 101371     UES(mini loft)Clean flex room (Female Only)  76384585618
# 101372                     Luxury Loft in Williamsburg   5156600288
#
#        host_identity_verified         host_name neighbourhood_group  \
# 156                  verified             James           Manhattan
# ...

# %%
df.country_code.unique()
# Out:
# <ArrowStringArray>
# ['US', nan]
# Length: 2, dtype: str

# %%
# if there exist different country, but here just one country exist
df.loc[(df['country_code'] == 'US') & (df['country'].isnull()),'country'] = 'United States'

# %%
df.isnull().sum()
# Out:
# name                          0
# host_id                       0
# host_identity_verified        0
# host_name                     0
# neighbourhood_group           0
# neighbourhood                 0
# lat                           0
# long                          0
# country                      79
# country_code                115
# instant_bookable             89
# cancellation_policy          67
# room_type                     0
# construction_year           186
# price                       233
# service_fee                 267
# minimum_nights              384
# number_of_reviews           182
# last_review               15674
# dtype: int64

# %%
df['country'].unique()
# Out:
# <ArrowStringArray>
# ['United States', nan]
# Length: 2, dtype: str

# %%
# fill with United states 
df['country'] = df['country'].fillna('United States')

# %%
df.loc[(df['country'] == 'United States') & (df['country_code'].isnull()), 'country_code'] = 'US'

# %%
df.isnull().sum()
# Out:
# name                          0
# host_id                       0
# host_identity_verified        0
# host_name                     0
# neighbourhood_group           0
# neighbourhood                 0
# lat                           0
# long                          0
# country                       0
# country_code                  0
# instant_bookable             89
# cancellation_policy          67
# room_type                     0
# construction_year           186
# price                       233
# service_fee                 267
# minimum_nights              384
# number_of_reviews           182
# last_review               15674
# dtype: int64

# %%
df.dropna(subset=['instant_bookable', 'cancellation_policy','construction_year', 'price', 'service_fee', 'minimum_nights',
       'number_of_reviews'], inplace = True)

# %%
df.isnull().sum()
# Out:
# name                          0
# host_id                       0
# host_identity_verified        0
# host_name                     0
# neighbourhood_group           0
# neighbourhood                 0
# lat                           0
# long                          0
# country                       0
# country_code                  0
# instant_bookable              0
# cancellation_policy           0
# room_type                     0
# construction_year             0
# price                         0
# service_fee                   0
# minimum_nights                0
# number_of_reviews             0
# last_review               15408
# dtype: int64

# %%
df.head()
# Out:
#                                                name      host_id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host_name neighbourhood_group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 4               verified    Lyndon           Manhattan         East Harlem
# 5               verified  Michelle           Manhattan         Murray Hill
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country_code instant_bookable  \
# ...

# %% [markdown]
# #### Remove `$` and `,` sign from `price` and `service_fee` columns

# %%
df['price'] = df['price'].str.replace('[$,]','',regex=True).astype(float)

# %%
df['service_fee'].str.replace('$','', regex=False).astype(float).max()
# Out:
# 240.0

# %%
df['service_fee'] = df['service_fee'].str.replace('$','', regex=False).astype(float)

# %%
df[['price','service_fee']]
# Out:
#          price  service_fee
# 0        966.0        193.0
# 1        142.0         28.0
# 4        204.0         41.0
# 5        577.0        115.0
# 7       1060.0        212.0
# ...        ...          ...
# 102029   822.0        164.0
# 102030   455.0         91.0
# 102031  1078.0        216.0
# 102032   103.0         21.0
# 102040   982.0        196.0
#
# [99812 rows x 2 columns]

# %%
df.head()
# Out:
#                                                name      host_id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host_name neighbourhood_group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 4               verified    Lyndon           Manhattan         East Harlem
# 5               verified  Michelle           Manhattan         Murray Hill
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country_code instant_bookable  \
# ...

# %%
df['construction_year'] = df['construction_year'].astype(int)

# %%
df['minimum_nights'].min() #maybe wrong data entry problem fixed it by make absolute value
# Out:
# -1223.0

# %%
df[df['minimum_nights']<0]
# Out:
#                                                     name      host_id  \
# 176                  BROOKLYN VICTORIAN STYLE SUITE.....  83631499592
# 398                   SUPER BIG AND COZY PRIVATE BEDROOM  50336791874
# 421                          Charming Nolita Apartment!!   7389895192
# 441                       Cozy apartment in a brownstone  81186886194
# 478                   Charming upper west side apartment  89878315253
# 525    Chateau Style Brooklyn Loft for Singles or Cou...   2631536622
# 42446            Cozy room in bright, spacious apartment  84040511136
# 42500  2bd BOUTIQUE  Apartament in the heart of MANHA...   2679070022
# 42538                   Newly Renovated Garden Apartment  98469733112
# 69749                Amazing location! 10ft from L train  62132542936
# 91271                 Beautiful modern & large 2 bedroom  13861414317
# 91357                            Cozy Brooklyn Apartment  63988893317
#
# ...

# %%
df['minimum_nights'].abs().max()   # look like outlier. capping it the upper value 30
# Out:
# 5645.0

# %%
df['minimum_nights'] = df['minimum_nights'].abs()

# %%
df[df['minimum_nights'] > 30]
# Out:
#                                                    name      host_id  \
# 7                                       BlissArtsSpace!  90821839709
# 37                          Clean and Quiet in Brooklyn  26207748876
# 82                 Spacious luminous apt Upper West NYC  97798221815
# 164                  Luxurious Condo in DUBMO with View  20270952150
# 165     Charming & Cozy midtown loft any WEEK ENDS  !!!   3310140241
# ...                                                 ...          ...
# 101667     Charming 1 Bedroom in center of East Village  74880950520
# 101796                 Small Cozy Room in Herald Square  68953119258
# 101842                     Beautiful duplex in Gramercy  89855789531
# 101980      NYU/E.Village Cafes & Bars*6 month $3500/mo  61716466230
# 102010                                  Brooklyn Style!  35669070960
#
#        host_identity_verified host_name neighbourhood_group  \
# 7                 unconfirmed      Emma            Brooklyn
# ...

# %%
df['minimum_nights'].describe()
# Out:
# count    99812.000000
# mean         8.120597
# std         30.359856
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          5.000000
# max       5645.000000
# Name: minimum_nights, dtype: float64

# %%
df['minimum_nights'] = df['minimum_nights'].clip(upper=30)

# %%
df['minimum_nights'].describe()
# Out:
# count    99812.000000
# mean         6.914640
# std          9.734979
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          5.000000
# max         30.000000
# Name: minimum_nights, dtype: float64

# %%
df.head()
# Out:
#                                                name      host_id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host_name neighbourhood_group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 4               verified    Lyndon           Manhattan         East Harlem
# 5               verified  Michelle           Manhattan         Murray Hill
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country_code instant_bookable  \
# ...

# %%
df['price'].describe()
# Out:
# count    99812.000000
# mean       625.364385
# std        331.638541
# min         50.000000
# 25%        340.000000
# 50%        624.000000
# 75%        913.000000
# max       1200.000000
# Name: price, dtype: float64

# %%
df['number_of_reviews'].describe()
# Out:
# count    99812.000000
# mean        27.366529
# std         49.322255
# min          0.000000
# 25%          1.000000
# 50%          7.000000
# 75%         30.000000
# max       1024.000000
# Name: number_of_reviews, dtype: float64

# %%
df.head()
# Out:
#                                                name      host_id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host_name neighbourhood_group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 4               verified    Lyndon           Manhattan         East Harlem
# 5               verified  Michelle           Manhattan         Murray Hill
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country_code instant_bookable  \
# ...

# %%
df['neighbourhood_group'].unique()
# Out:
# <ArrowStringArray>
# ['Brooklyn', 'Manhattan', 'brookln', 'Queens', 'Staten Island', 'Bronx']
# Length: 6, dtype: str

# %% [markdown]
# #### here Brooklyn and brookln are the same, replce brookln by Brooklyn

# %%
df['neighbourhood_group'] = df['neighbourhood_group'].replace('brookln','Brooklyn')

# %%
df['neighbourhood_group'].unique()
# Out:
# <ArrowStringArray>
# ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx']
# Length: 5, dtype: str

# %%
df['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Bedford-Stuyvesant        7722
# Williamsburg              7550
# Harlem                    5302
# Bushwick                  4856
# Hell's Kitchen            3885
#                           ...
# Willowbrook                  3
# Gerritsen Beach              3
# Fort Wadsworth               2
# Glen Oaks                    2
# Chelsea, Staten Island       1
# Name: count, Length: 224, dtype: int64

# %%
df['room_type'].unique()
# Out:
# <ArrowStringArray>
# ['Private room', 'Entire home/apt', 'Shared room', 'Hotel room']
# Length: 4, dtype: str

# %%
df['cancellation_policy'].unique()
# Out:
# <ArrowStringArray>
# ['strict', 'moderate', 'flexible']
# Length: 3, dtype: str

# %%
df['instant_bookable'].unique()
# Out:
# array([False, True], dtype=object)

# %%
df['instant_bookable'] = df['instant_bookable'].apply(lambda x: 1 if x == True else 0)

# %%
df.head()
# Out:
#                                                name      host_id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host_name neighbourhood_group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 4               verified    Lyndon           Manhattan         East Harlem
# 5               verified  Michelle           Manhattan         Murray Hill
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country_code  instant_bookable  \
# ...

# %%
df.to_csv('airbnb_cleaned.csv', index = False)
